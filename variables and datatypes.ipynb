# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and

# %%
a="hello world"
print(a[:2])
# Out:
# he

# %%
a="sanjay bennur"
print(a[:-2])
# Out:
#   Cell In[6], line 3
#     print(1:5)
#            ^
# SyntaxError: invalid syntax

# %%
a="sanjay bennur"
print(a[1:7])
# Out:
# anjay

# %%
a="hello world"
print(a[::-1])
# Out:
# dlrow olleh

# %%
a="hello world"
print(a[::-2])
# Out:
# drwolh

# %%
a="hello world"
print(a[::2])
# Out:
# hlowrd

# %%
a="hello world"
print(a[2::])
# Out:
# llo world

# %%
a="hello world"
print(a[-2::])
# Out:
# ld

# %%
a="hello world"
print(a[::-4])
# Out:
# dwl

# %%
a=int(input())
if a>0 and a%2==0:
    print("positive and even")
elif a<0 and a%2!=0:
    print("Negative and odd number")
elif a<0:
    print("negative integer")
else:
    print("zero")
# Out:
#  -7
# Negative and odd number

# %%
num = 123
num_str = str(num)
print(num_str)         # Output: "123"
print(type(num_str))   # Output: <class 'str'>
# Out:
# 123
# <class 'str'>

# %%
a=34.54
print(type(a))
# Out:
# <class 'float'>

# %%
num = 100
num_float = float(num)
print(num_float)       # Output: 100.0
print(type(num_float)) # Output: <class 'float'>
# Out:
# 100.0
# <class 'float'>

# %%
num=100
a=float(num)
print(a)
print(type(a))
# Out:
# 100.0
# <class 'float'>

# %%
a=(' ramu ')
b=(f"hello{a}welcome")
print(b)
# Out:
# hello ramu welcome

# %%
# Define variables
name = "John"         # String variable
age = 30              # Integer variable
height = 5.9          # Float variable
is_student = False    # Boolean variable

# Print the variables
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is a student:", is_student)

# Modify a variable
age = age + 1
print("Updated Age:", age)
# Out:
# Name: John
# Age: 30
# Height: 5.9
# Is a student: False
# Updated Age: 31

# %%
# Function to greet the user
def greet(name):
    print("Hello,", name)

# Calling the function
greet("Alice")
# Out:
# Hello, Alice

# %%
import math

# Given radius
radius = 10

# Calculate area
area = math.pi * (radius ** 2)

# Display the result
print("The area of the circle with radius", radius, "is:", area)
# Out:
# The area of the circle with radius 10 is: 314.1592653589793

# %%
a="123"
b=a[::-1]
print(b)
# Out:
# 321

# %%
a="sfdfgfdgf cgb"
b=a[::-1]
b
# Out:
# 'bgc fgdfgfdfs'

# %%
a=1
b=2
c=a+b
c
# Out:
# 3

# %%
a=1
b=2
print("addition:",a+b)
# Out:
# addition: 3

# %%
a = True
b = False
result = a or b  
print(result)# result is False
# Out:
# True

# %%
x="all is well"
b=x[::-1]
print(b)
# Out:
# llew si lla

# %%
x=input("enter your faviourate color:")
y=float(input("Enter decimal value:"))
print(x,y)
b=int(y)
print(b,type(b))
print(b**2)
# Out:
# enter your faviourate color: sanju
# Enter decimal value: 23
# sanju 23.0
# 23 <class 'int'>
# 529

# %%
x=input()
y=int(input())
print(x,y)
a=int(y)
print(type(a))
print(a**2)
# Out:
#  sanju
#  4
# sanju 4
# <class 'int'>
# 16

# %%
a=int(input())
b=int(input())
a=a+b
b=a-b
a=a-b
print(a)
print(b)
# Out:
#  2
#  3
# 3
# 2

# %%
a=int(input())
b=int(input())
c=int(input())
a=a+b+c
b=a-b-c
c=a-b-c
a=a-b-c
print(a)
print(b)
print(c)
# Out:
#  1
#  2
#  3
# 3
# 1
# 2

# %%
a=1
b=4
c=a
a=b
b=c
print(a)
print(b)
# Out:
# 4
# 1

# %%
a=int(input())
b=int(input())
if a>b:
    print("a is greater:",a)
else:
    print("b is greater:",b)
# Out:
#  56
#  34
# a is greater: 56

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("a greater:",a)
elif b>c and b>a:
    print("b greater:",b)
else:
    print("c greater",c)
# Out:
#  2
#  7
#  1
# b greater: 7

# %%
a=int(input())
b=int(input())
c=int(input())
if (a>b and a<c) or (a<b and a>c):
    print("second largest is:",a)
elif(b>c and b<a) or (b<c and b>a):
    print("second largest is:",b)
else:
    print("second largest is:",c)
# Out:
#  1
#  2
#  3
# second largest is: 2

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
if a<=b and a<=c and a<=d:
    print("a is small",a)
elif b<=c and b<=d and b<=a:
    print("b is small",b)
elif c<=d and c<=a and c<=b:
    print("c is small",c)
else:
    print("d is small",d)
# Out:
#  7
#  6
#  1
#  4
# c is small 1

# %%
a=int(input())
if a%2==0:
    print("given number is even")
else:
    print("given number is odd")
# Out:
#  9
# given number is odd

# %%
a=int(input())
if a>0:
    print("positive")
elif a<0:
    print("negative")
else:
    print("the number is 0")
# Out:
#  -45
# negative

# %%
for i in range(1,6):
    for j in range(1,i+1):
       print(i,end='')
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
