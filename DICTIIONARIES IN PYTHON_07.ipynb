# %%
                     #DICTIONARY___       #07-VIDIO    #11/11/2024

ka={
   "davangere":"Nenne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
print(ka)
# Out:
# {'davangere': 'Nenne Dosa', 'mysore': 'mysore pak', 'darwad': 'peda'}

# %%
(ka["mysore"])
# Out:
# 'mysore pak'

# %%
print(type(ka))
# Out:
# <class 'dict'>

# %%
          #if we give outside output of the code the code not give error if we put (.get)data.
        #if did'nt give it show error
ka={
   "davangere":"Nenne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
print(ka)
print(ka["mysore"])
print(ka.get("shivmoga","NOt Found"))
# Out:
# {'davangere': 'Nenne Dosa', 'mysore': 'mysore pak', 'darwad': 'peda'}
# mysore pak
# NOt Found

# %%
ka={                                 #Error Showing
   "davangere":"Nenne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
print(ka["chiradurga"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 6
#       1 ka={                                 #Error Showing
#       2    "davangere":"Nenne Dosa",
#       3    "mysore":"mysore pak",
#       4    "darwad":"peda"
#       5 }
# ----> 6 print(ka["chiradurga"])
#
# KeyError: 'chiradurga'

# %%
                #ADDING DICTONARY
ka={
   "davangere":"Nenne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
print(ka)
ka["benglur"]="palav"
print("after adding")
print(ka)
# Out:
# {'davangere': 'Nenne Dosa', 'mysore': 'mysore pak', 'darwad': 'peda'}
# after adding
# {'davangere': 'Nenne Dosa', 'mysore': 'mysore pak', 'darwad': 'peda', 'benglur': 'palav'}

# %%
            #UPDATING DICTIONARY
        #if did'nt give it show error
ka={
   "davangere":"Nenne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
ka["darwad"]="jillabe"
print(ka)
# Out:
# {'davangere': 'Nenne Dosa', 'mysore': 'mysore pak', 'darwad': 'jillabe'}

# %%
            #REMOVING DICTIONARY
        #if did'nt give it show error
ka={
   "davangere":"benne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
del ka["mysore"]       #deleting the data
ka.pop("davangere")    #deleting the data
print(ka)
# Out:
# {'darwad': 'peda'}

# %%
                  # IT GIVES THE KEY LIST AND VALUES CODE
ka={
   "davangere":"benne Dosa",
   "mysore":"mysore pak",
   "darwad":"peda" 
}
print(ka.keys())
print(ka.values())
print(ka.items())           #IT GIVES SEPPERATE LIST
# Out:
# dict_keys(['davangere', 'mysore', 'darwad'])
# dict_values(['benne Dosa', 'mysore pak', 'peda'])
# dict_items([('davangere', 'benne Dosa'), ('mysore', 'mysore pak'), ('darwad', 'peda')])
