# %%
a=int(input())
for i in range(a):
    print('****')
# Out:
#  4
# ****
# ****
# ****
# ****

# %%
n=int(input())
for i in range(n):
    for j in range(0,i+1):
       print('*',end="")
    print()
# Out:
#  5
# *
# **
# ***
# ****
# *****

# %%
n=int(input())
for i in range(0,n):
    print(" "*(n-i),end="")
    for j in range(0,i+1):
        print("*",end="")
    print()
# Out:
#  5
#      *
#     **
#    ***
#   ****
#  *****

# %%
 n=int(input())
for i in range(n):
    for j in range(i):
       print(end="  ")
    print('****')
# Out:
#  6
# ****
#   ****
#     ****
#       ****
#         ****
#           ****

# %%
n=int(input())
for i in range(0,n):
    print(" "*(n-i),end="")
    for j in range(0,i+1):
       print("*",end=" ")
    print()
# Out:
#  6
#       *
#      * *
#     * * *
#    * * * *
#   * * * * *
#  * * * * * *

# %%
n=int(input())
m=int(input())
for i in range(n):
    for j in range(m):
        if i==0 or i==n-1 or j==0 or j==m-1:
            print("*",end=" ")
        else:
            print(' ',end=" ")      
    print()
# Out:
#  5
#  7
# * * * * * * *
# *           *
# *           *
# *           *
# * * * * * * *

# %%
n=int(input())
for i in range(n):
    if i==0 or i==3:
        print("*"*n)
    else:
        print("***")
# Out:
#  7
# *******
# ***
# ***
# *******
# ***
# ***
# ***

# %%
for i in range(5,0,-1):
    for j in range(,0-1):
        print("*",end=" ")
        print()
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
