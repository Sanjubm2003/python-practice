# %%
          #Lists                      #10/11/2024    #5-vidio

item=["sugar","coffe","1sugar","juce"]
a=item[::2]
b=item[1::]
item.pop(1)
print(item)
print(a)
print(b)
# Out:
# ['sugar', '1sugar', 'juce']
# ['sugar', '1sugar']
# ['coffe', '1sugar', 'juce']

# %%
                                                           #insert items
item=["sugar","coffe","1sugar","juce"]                    
item.insert(1,"cup")
print(item)
# Out:
# ['sugar', 'cup', 'coffe', '1sugar', 'juce']

# %%
item=["sugar","coffe","1sugar","juce"]                     #clear all items
item.clear()
print(item)
# Out:
# []

# %%
item=["sugar","coffe","1sugar","juce"]                      #Modify the items
item[1]="Tea"
print(item)
print(item[0:2])
# Out:
# ['sugar', 'Tea', '1sugar', 'juce']
# ['sugar', 'Tea']

# %%
a=[3,5,25,6,8,2]               #sorted in assending
print(sorted(a))
# Out:
# [2, 3, 5, 6, 8, 25]

# %%
a=[3,5,25,6,8,2]              #sorted in desending
sort=sorted(a)
b=sort.reverse()
print(a)
# Out:
# [3, 5, 25, 6, 8, 2]

# %%
a=[[1,2],[3,4]]
print(a[1][1])
# Out:
# 4
